# %%
import pandas as pd

# %%
refseq_metadata = pd.read_csv("assembly_summary.txt",sep='\t',skiprows=[0],dtype='str')

# %%
refseq_metadata.columns
# Out:
# Index(['#assembly_accession', 'bioproject', 'biosample', 'wgs_master',
#        'refseq_category', 'taxid', 'species_taxid', 'organism_name',
#        'infraspecific_name', 'isolate', 'version_status', 'assembly_level',
#        'release_type', 'genome_rep', 'seq_rel_date', 'asm_name',
#        'asm_submitter', 'gbrs_paired_asm', 'paired_asm_comp', 'ftp_path',
#        'excluded_from_refseq', 'relation_to_type_material',
#        'asm_not_live_date', 'assembly_type', 'group', 'genome_size',
#        'genome_size_ungapped', 'gc_percent', 'replicon_count',
#        'scaffold_count', 'contig_count', 'annotation_provider',
#        'annotation_name', 'annotation_date', 'total_gene_count',
#        'protein_coding_gene_count', 'non_coding_gene_count', 'pubmed_id'],
#       dtype='object')

# %%
patric_summary = pd.read_csv("genome_summary",sep='\t')

# %%
patric_summary
# Out:
#          genome_id                                        genome_name  \
# 0         469009.4          "'Brassica napus' phytoplasma strain TW1"
# 1        1309411.5     "'Deinococcus soli' Cha et al. 2014 strain N5"
# 2        1123738.3  "'Echinacea purpurea' witches'-broom phytoplas...
# 3         551115.6                            "'Nostoc azollae' 0708"
# 4        1856298.3  "'Osedax' symbiont bacterium Rs2_46_30_T18 str...
# ...            ...                                                ...
# 1059041  1131286.3               zeta proteobacterium SCGC AB-137-J06
# 1059042  1131287.3               zeta proteobacterium SCGC AB-602-C20
# 1059043  1131288.3               zeta proteobacterium SCGC AB-602-E04
# 1059044  1131289.3               zeta proteobacterium SCGC AB-604-B04
# 1059045  1131290.3               zeta proteobacterium SCGC AB-604-O16
#
#          taxon_id genome_status  genome_length  gc_content  contig_l50  \
# 0          469009           WGS         743598    27.23313         1.0
# 1         1309411      Complete        3236984    70.20000         1.0
# 2         1123738           WGS         545427    23.89000         4.0
# 3          551115      Complete        5486145    38.30000         1.0
# 4         1856298           WGS        4021833    45.76000        63.0
# ...           ...           ...            ...         ...         ...
# 1059041   1131286           WGS         884635    46.70000        11.0
# 1059042   1131287           WGS         987314    46.22000        22.0
# 1059043   1131288           WGS         451985    46.18000        18.0
# 1059044   1131289           WGS         944583    50.33000        19.0
# 1059045   1131290           WGS         979689    50.50000        11.0
#
#          contig_n50  chromosomes  plasmids  contigs  patric_cds  refseq_cds  \
# 0          373899.0          NaN       NaN        5      1073.0       705.0
# 1         3236984.0          1.0       NaN        1      3197.0      2944.0
# 2           46697.0          NaN       NaN       28       535.0       433.0
# 3         5354700.0          1.0       2.0        3      7014.0      3651.0
# 4           19390.0          NaN       NaN      365      4118.0      3690.0
# ...             ...          ...       ...      ...         ...         ...
# 1059041     19981.0          0.0       0.0      122       946.0         0.0
# 1059042     14661.0          0.0       0.0      128      1016.0         0.0
# 1059043      5881.0          0.0       0.0      101       470.0         0.0
# 1059044     15090.0          0.0       0.0      132      1076.0         0.0
# 1059045     23039.0          0.0       0.0       97      1086.0         0.0
#
#          trna  rrnacoarse_consistency  fine_consistency  checkm_completeness  \
# 0        27.0                     NaN              98.2                100.0
# 1        50.0                     NaN              98.1                 96.9
# 2        26.0                     NaN              94.6                 84.0
# 3         0.0                     NaN              99.2                 99.3
# 4        59.0                     NaN              88.3                 98.7
# ...       ...                     ...               ...                  ...
# 1059041   8.0                     NaN              84.8                 32.2
# 1059042  12.0                     NaN              87.7                 24.3
# 1059043   3.0                     NaN              93.4                  8.0
# 1059044  11.0                     NaN              88.1                 44.6
# 1059045  19.0                     NaN              85.7                 42.4
#
#          checkm_contamination  genome_qualitydate_created  \
# 0                        10.3                         NaN
# 1                         1.0                         NaN
# 2                         6.4                         NaN
# 3                         0.7                         NaN
# 4                         3.1                         NaN
# ...                       ...                         ...
# 1059041                   3.1                         NaN
# 1059042                  17.0                         NaN
# 1059043                  11.0                         NaN
# 1059044                   4.3                         NaN
# 1059045                   6.6                         NaN
#
#                     date_modified
# 0        2018-07-15T20:38:31.410Z
# 1        2016-01-17T16:02:31.274Z
# 2        2016-01-17T17:13:35.332Z
# 3        2015-03-16T03:17:09.594Z
# 4        2017-07-22T04:04:17.224Z
# ...                           ...
# 1059041  2015-03-16T03:17:09.594Z
# 1059042  2015-03-16T03:17:09.594Z
# 1059043  2015-03-16T03:17:09.594Z
# 1059044  2015-03-16T03:17:09.594Z
# 1059045  2015-03-16T03:17:09.594Z
#
# [1059046 rows x 20 columns]

# %%
patric_metadata = pd.read_csv("genome_metadata",sep='\t',dtype='str')

# %%
patric_metadata
# Out:
#          genome_id                                        genome_name  \
# 0         469009.4          "'Brassica napus' phytoplasma strain TW1"
# 1        1309411.5     "'Deinococcus soli' Cha et al. 2014 strain N5"
# 2        1123738.3  "'Echinacea purpurea' witches'-broom phytoplas...
# 3         551115.6                            "'Nostoc azollae' 0708"
# 4        1856298.3  "'Osedax' symbiont bacterium Rs2_46_30_T18 str...
# ...            ...                                                ...
# 1059041  1131286.3               zeta proteobacterium SCGC AB-137-J06
# 1059042  1131287.3               zeta proteobacterium SCGC AB-602-C20
# 1059043  1131288.3               zeta proteobacterium SCGC AB-602-E04
# 1059044  1131289.3               zeta proteobacterium SCGC AB-604-B04
# 1059045  1131290.3               zeta proteobacterium SCGC AB-604-O16
#
#                                 organism_name taxon_id genome_status  \
# 0                                         NaN   469009           WGS
# 1                                         NaN  1309411      Complete
# 2                                         NaN  1123738           WGS
# 3                       'Nostoc azollae' 0708   551115      Complete
# 4                                         NaN  1856298           WGS
# ...                                       ...      ...           ...
# 1059041  zeta proteobacterium SCGC AB-137-J06  1131286           WGS
# 1059042  zeta proteobacterium SCGC AB-602-C20  1131287           WGS
# 1059043  zeta proteobacterium SCGC AB-602-E04  1131288           WGS
# 1059044  zeta proteobacterium SCGC AB-604-B04  1131289           WGS
# 1059045  zeta proteobacterium SCGC AB-604-O16  1131290           WGS
#
#                   strain serovar biovar pathovar mlst  ... motility  \
# 0                    TW1     NaN    NaN      NaN  NaN  ...      NaN
# 1                     N5     NaN    NaN      NaN  NaN  ...      NaN
# 2               NCHU2014     NaN    NaN      NaN  NaN  ...      NaN
# 3                    708     NaN    NaN      NaN  NaN  ...      Yes
# 4          Rs2_46_30_T18     NaN    NaN      NaN  NaN  ...      NaN
# ...                  ...     ...    ...      ...  ...  ...      ...
# 1059041  SCGC AB-137-J06     NaN    NaN      NaN  NaN  ...      NaN
# 1059042  SCGC AB-602-C20     NaN    NaN      NaN  NaN  ...      NaN
# 1059043  SCGC AB-602-E04     NaN    NaN      NaN  NaN  ...      NaN
# 1059044  SCGC AB-604-B04     NaN    NaN      NaN  NaN  ...      NaN
# 1059045  SCGC AB-604-O16     NaN    NaN      NaN  NaN  ...      NaN
#
#         sporulation temperature_range optimal_temperature salinity  \
# 0               NaN               NaN                 NaN      NaN
# 1               NaN               NaN                 NaN      NaN
# 2               NaN               NaN                   C      NaN
# 3               NaN        Mesophilic                   -      NaN
# 4               NaN               NaN                 NaN      NaN
# ...             ...               ...                 ...      ...
# 1059041         NaN               NaN                 NaN      NaN
# 1059042         NaN               NaN                 NaN      NaN
# 1059043         NaN               NaN                 NaN      NaN
# 1059044         NaN               NaN                 NaN      NaN
# 1059045         NaN               NaN                 NaN      NaN
#
#         oxygen_requirement   habitat disease  \
# 0                      NaN       NaN     NaN
# 1                      NaN       NaN     NaN
# 2                      NaN       NaN     NaN
# 3                  Aerobic  Multiple     NaN
# 4                      NaN       NaN     NaN
# ...                    ...       ...     ...
# 1059041                NaN       NaN     NaN
# 1059042                NaN       NaN     NaN
# 1059043                NaN       NaN     NaN
# 1059044                NaN       NaN     NaN
# 1059045                NaN       NaN     NaN
#
#                                                   comments  \
# 0        Genome sequence of a strain of bacteria that c...
# 1        Genome sequencing of a Gamma-Radiation-Resista...
# 2        'Echinacea purpurea' witches'-broom phytoplasm...
# 3        Nostoc azollae 0708. Nostoc azollae 0708, also...
# 4        In this study, we simulate the Deepwater Horiz...
# ...                                                    ...
# 1059041  Single cell genome sequencing of biomineralizi...
# 1059042  Single cell genome sequencing of biomineralizi...
# 1059043  Single cell genome sequencing of biomineralizi...
# 1059044  Single cell genome sequencing of biomineralizi...
# 1059045  Single cell genome sequencing of biomineralizi...
#
#                                        additional_metadata
# 0        sample_type:metagenomic assembly;collected_by:...
# 1                                    sample_type:bacterial
# 2                             lab_host:Catharanthus roseus
# 3                                                      NaN
# 4                         sample_type:metagenomic assembly
# ...                                                    ...
# 1059041                                                NaN
# 1059042                                                NaN
# 1059043                                                NaN
# 1059044                                                NaN
# 1059045                                                NaN
#
# [1059046 rows x 66 columns]

# %%
patric_metadata['refseq_accessions']
# Out:
# 0                                    NaN
# 1                          NZ_CP011389.1
# 2                                    NaN
# 3          NC_014248,NC_014249,NC_014250
# 4                                    NaN
#                        ...
# 1059041                                -
# 1059042                                -
# 1059043                                -
# 1059044                                -
# 1059045                                -
# Name: refseq_accessions, Length: 1059046, dtype: object

# %%
patric_metadata_filtered = patric_metadata[patric_metadata['refseq_accessions'].notna()]
patric_metadata_filtered
# Out:
#          genome_id                                     genome_name  \
# 1        1309411.5  "'Deinococcus soli' Cha et al. 2014 strain N5"
# 3         551115.6                         "'Nostoc azollae' 0708"
# 34        483218.5        "[Bacteroides] pectinophilus ATCC 43243"
# 35       1232385.4                  "[Brevibacterium] flavum ZL-1"
# 36         92706.3     "[Brevibacterium] flavum strain ATCC 15168"
# ...            ...                                             ...
# 1059041  1131286.3            zeta proteobacterium SCGC AB-137-J06
# 1059042  1131287.3            zeta proteobacterium SCGC AB-602-C20
# 1059043  1131288.3            zeta proteobacterium SCGC AB-602-E04
# 1059044  1131289.3            zeta proteobacterium SCGC AB-604-B04
# 1059045  1131290.3            zeta proteobacterium SCGC AB-604-O16
#
#                                 organism_name taxon_id genome_status  \
# 1                                         NaN  1309411      Complete
# 3                       'Nostoc azollae' 0708   551115      Complete
# 34       Bacteroides pectinophilus ATCC 43243   483218           WGS
# 35                                        NaN  1232385      Complete
# 36                                        NaN    92706      Complete
# ...                                       ...      ...           ...
# 1059041  zeta proteobacterium SCGC AB-137-J06  1131286           WGS
# 1059042  zeta proteobacterium SCGC AB-602-C20  1131287           WGS
# 1059043  zeta proteobacterium SCGC AB-602-E04  1131288           WGS
# 1059044  zeta proteobacterium SCGC AB-604-B04  1131289           WGS
# 1059045  zeta proteobacterium SCGC AB-604-O16  1131290           WGS
#
#                   strain serovar biovar pathovar mlst  ... motility  \
# 1                     N5     NaN    NaN      NaN  NaN  ...      NaN
# 3                    708     NaN    NaN      NaN  NaN  ...      Yes
# 34            ATCC 43243     NaN    NaN      NaN  NaN  ...       No
# 35                  ZL-1     NaN    NaN      NaN  NaN  ...      NaN
# 36            ATCC 15168     NaN    NaN      NaN  NaN  ...      NaN
# ...                  ...     ...    ...      ...  ...  ...      ...
# 1059041  SCGC AB-137-J06     NaN    NaN      NaN  NaN  ...      NaN
# 1059042  SCGC AB-602-C20     NaN    NaN      NaN  NaN  ...      NaN
# 1059043  SCGC AB-602-E04     NaN    NaN      NaN  NaN  ...      NaN
# 1059044  SCGC AB-604-B04     NaN    NaN      NaN  NaN  ...      NaN
# 1059045  SCGC AB-604-O16     NaN    NaN      NaN  NaN  ...      NaN
#
#         sporulation temperature_range optimal_temperature salinity  \
# 1               NaN               NaN                 NaN      NaN
# 3               NaN        Mesophilic                   -      NaN
# 34               No        Mesophilic               35-40      NaN
# 35              NaN               NaN                 NaN      NaN
# 36              NaN               NaN                 NaN      NaN
# ...             ...               ...                 ...      ...
# 1059041         NaN               NaN                 NaN      NaN
# 1059042         NaN               NaN                 NaN      NaN
# 1059043         NaN               NaN                 NaN      NaN
# 1059044         NaN               NaN                 NaN      NaN
# 1059045         NaN               NaN                 NaN      NaN
#
#         oxygen_requirement          habitat disease  \
# 1                      NaN              NaN     NaN
# 3                  Aerobic         Multiple     NaN
# 34               Anaerobic  Host-associated     NaN
# 35                     NaN              NaN     NaN
# 36                     NaN              NaN     NaN
# ...                    ...              ...     ...
# 1059041                NaN              NaN     NaN
# 1059042                NaN              NaN     NaN
# 1059043                NaN              NaN     NaN
# 1059044                NaN              NaN     NaN
# 1059045                NaN              NaN     NaN
#
#                                                   comments  \
# 1        Genome sequencing of a Gamma-Radiation-Resista...
# 3        Nostoc azollae 0708. Nostoc azollae 0708, also...
# 34       Bacteroides pectinophilus  ATCC 43243. Bactero...
# 35                              Produces lysine, L-lysine.
# 36             metabolic engineering for valine production
# ...                                                    ...
# 1059041  Single cell genome sequencing of biomineralizi...
# 1059042  Single cell genome sequencing of biomineralizi...
# 1059043  Single cell genome sequencing of biomineralizi...
# 1059044  Single cell genome sequencing of biomineralizi...
# 1059045  Single cell genome sequencing of biomineralizi...
#
#              additional_metadata
# 1          sample_type:bacterial
# 3                            NaN
# 34                           NaN
# 35                           NaN
# 36       sample_type:Single cell
# ...                          ...
# 1059041                      NaN
# 1059042                      NaN
# 1059043                      NaN
# 1059044                      NaN
# 1059045                      NaN
#
# [31666 rows x 66 columns]

# %%
patric_metadata_filtered = patric_metadata[patric_metadata['assembly_accession'].notna()]
patric_metadata_filtered['assembly_accession']
# Out:
# 0          GCA_003181115.1
# 1          GCF_001007995.1
# 2          GCF_001307505.1
# 3          GCA_000196515.1
# 4          GCA_002163025.1
#                 ...
# 1059041    GCA_000379245.1
# 1059042    GCA_000379345.1
# 1059043    GCA_000379265.1
# 1059044    GCA_000379205.1
# 1059045    GCA_000372125.1
# Name: assembly_accession, Length: 828228, dtype: object

# %%
refseq_metadata_filtered = refseq_metadata[refseq_metadata['#assembly_accession'].notna()]
refseq_metadata_filtered['#assembly_accession']
# Out:
# 0         GCF_036600855.1
# 1         GCF_036600875.1
# 2         GCF_036600895.1
# 3         GCF_036600915.1
# 4         GCF_900128725.1
#                ...
# 404913    GCF_046824975.1
# 404914    GCF_028826155.1
# 404915    GCF_046825355.1
# 404916    GCF_037013405.1
# 404917    GCF_042466685.1
# Name: #assembly_accession, Length: 404918, dtype: object

# %%
merged_df = pd.merge(refseq_metadata_filtered, patric_metadata_filtered, left_on='#assembly_accession', right_on='assembly_accession', how='inner')
merged_df
# Out:
#       #assembly_accession   bioproject     biosample      wgs_master  \
# 0         GCF_900128725.1  PRJNA224116  SAMEA4556317              na
# 1         GCF_001589285.1  PRJNA224116  SAMN02639847  JEMA00000000.1
# 2         GCF_001442515.1  PRJNA224116  SAMN04158597              na
# 3         GCF_001598195.1  PRJNA224116  SAMN04544264              na
# 4         GCF_001012915.1  PRJNA224116  SAMN03283812  JXNB00000000.1
# ...                   ...          ...           ...             ...
# 42778     GCF_001690235.1  PRJNA224116  SAMN05179583  LZGO00000000.1
# 42779     GCF_001693435.1  PRJNA224116  SAMN05179591  LZGG00000000.1
# 42780     GCF_000708695.2  PRJNA224116  SAMN02644483  JENC00000000.1
# 42781     GCF_001431665.1  PRJNA224116  SAMN04207868  LLXV00000000.1
# 42782     GCF_001644665.1  PRJNA224116  SAMN02954477              na
#
#         refseq_category    taxid species_taxid  \
# 0                    na        9             9
# 1                    na       56            56
# 2                    na       69            69
# 3                    na      140           140
# 4                    na      159           159
# ...                 ...      ...           ...
# 42778                na  3120262       3120262
# 42779                na  3120264       3120264
# 42780                na  3344738        219574
# 42781  reference genome  3384461       3384461
# 42782  reference genome  3389972       3389972
#
#                             organism_name_x   infraspecific_name isolate  ...  \
# 0                       Buchnera aphidicola  strain=BCifornacula    2912  ...
# 1                      Sorangium cellulosum    strain=So0008-312      na  ...
# 2                    Lysobacter enzymogenes            strain=C3      na  ...
# 3                          Borrelia hermsii       strain=DAH-2E7      na  ...
# 4                Brachyspira hyodysenteriae    strain=FMV89.3323      na  ...
# ...                                     ...                  ...     ...  ...
# 42778                Gilliamella sp. wkB292        strain=wkB292      na  ...
# 42779                  Gilliamella sp. wkB7          strain=wkB7      na  ...
# 42780  Pseudomonas [fluorescens] ATCC 17400    strain=ATCC 17400      na  ...
# 42781               Stenotrophomonas beteli       strain=LMG 978      na  ...
# 42782      Fervidobacterium ngatamarikiense           strain=DYC      na  ...
#
#       motility sporulation temperature_range optimal_temperature salinity  \
# 0          NaN         NaN               NaN                 NaN      NaN
# 1          NaN         NaN               NaN                 NaN      NaN
# 2          NaN         NaN               NaN                 NaN      NaN
# 3          NaN         NaN               NaN                 NaN      NaN
# 4          NaN         NaN               NaN                 NaN      NaN
# ...        ...         ...               ...                 ...      ...
# 42778      NaN         NaN               NaN                 NaN      NaN
# 42779      NaN         NaN               NaN                 NaN      NaN
# 42780      Yes         NaN               NaN              26-28C      NaN
# 42781      NaN         NaN               NaN                   C      NaN
# 42782      NaN         NaN               NaN                 NaN      NaN
#
#       oxygen_requirement      habitat disease  \
# 0                    NaN          NaN     NaN
# 1                    NaN          NaN     NaN
# 2                    NaN          NaN     NaN
# 3                    NaN          NaN     NaN
# 4                    NaN          NaN     NaN
# ...                  ...          ...     ...
# 42778                NaN          NaN     NaN
# 42779                NaN          NaN     NaN
# 42780            Aerobic  Terrestrial     NaN
# 42781                NaN          NaN     NaN
# 42782                NaN          NaN     NaN
#
#                                                 comments  \
# 0      Within the Lachninae subfamily of aphids, a pu...
# 1      Sorangium cellulosum comparative genomic analysis
# 2      The genus Lysobacter consists of several plant...
# 3      Borrelia hermsii is the causative agent of tic...
# 4      confirms that the species is relatively conser...
# ...                                                  ...
# 42778  Genome sequence of Gilliamella apicola strains...
# 42779  Genome sequence of Gilliamella apicola strains...
# 42780  Whole genome sequence of P. fluorecens ATCC 17400
# 42781  To get insight into origin and evolution of St...
# 42782  A thermophilic strict anaerobe capable of cell...
#
#                                      additional_metadata
# 0      collected_by:Armelle Coeur D'Acier\; Emmanuell...
# 1                                                    NaN
# 2                                                    NaN
# 3                                collected_by:Tom Schwan
# 4                                                    NaN
# ...                                                  ...
# 42778                           sample_type:cell culture
# 42779                           sample_type:cell culture
# 42780                                                NaN
# 42781                         sample_type:whole organism
# 42782                                                NaN
#
# [42783 rows x 104 columns]

# %%
patric_metadata['taxon_id'].value_counts()
# Out:
# taxon_id
# 562        58906
# 1773       42792
# 1313       29643
# 573        28495
# 1280       19675
#            ...
# 180856         1
# 483218         1
# 1232385        1
# 429581         1
# 136143         1
# Name: count, Length: 104336, dtype: int64

# %%
refseq_metadata['taxid'].value_counts()
# Out:
# taxid
# 562        38429
# 573        21652
# 1280       13493
# 287        10229
# 470         9529
#            ...
# 3391431        1
# 3391430        1
# 3391429        1
# 3391428        1
# 3391427        1
# Name: count, Length: 83490, dtype: int64

# %%
ecoli = patric_metadata[patric_metadata['taxon_id']=='562']
ecoli['strain'].value_counts().head(20)
# Out:
# strain
# not applicable    661
# Fecal samples     634
# Not applicable     77
# not collected      67
# blood              46
# E. coli            43
# stool              33
# 131                27
# 10                 26
# 20                 19
# 15                 19
# E2                 19
# 16                 18
# 11                 18
# 17                 17
# 9                  16
# 4                  16
# 127                16
# ST73               16
# 7                  15
# Name: count, dtype: int64

# %%
ecoli = refseq_metadata[refseq_metadata['taxid']=='562']
ecoli['infraspecific_name'].value_counts().head(20)
# Out:
# infraspecific_name
# na                             1435
# strain=ST73                      16
# strain=E2                        12
# ecotype=Quinolone resistant      12
# strain=EC2                       12
# strain=EC1                       11
# strain=EC11                      10
# strain=EC3                       10
# strain=EC14                      10
# strain=10                         9
# strain=2                          9
# strain=15                         9
# strain=EC12                       9
# strain=EC13                       9
# strain=E4                         9
# strain=EC15                       9
# strain=K-12                       8
# strain=ECO3347                    8
# strain=12                         8
# strain=EC4                        8
# Name: count, dtype: int64

# %%
# Step 1: Filter by taxid 562 and strain 
df_taxid_562 = refseq_metadata[refseq_metadata['taxid'] == '562']
df_taxid_562 = df_taxid_562[df_taxid_562['infraspecific_name'] == 'strain=ST73']

# Step 2: Sort by the 'annotation_date' column (ensure it's in datetime format if necessary)
df_taxid_562['annotation_date'] = pd.to_datetime(df_taxid_562['annotation_date'])
df_taxid_562_sorted = df_taxid_562.sort_values(by='annotation_date', ascending=False)

# Step 3: Clean and convert 'genome_size' to numeric (if necessary)
df_taxid_562_sorted['genome_size'] = df_taxid_562_sorted['genome_size'].replace({r'[^\d.]': ''}, regex=True)
df_taxid_562_sorted['genome_size'] = pd.to_numeric(df_taxid_562_sorted['genome_size'], errors='coerce')

# Step 4: Select the latest assembly, and if there are still multiple rows, pick the one with the longest genome size
df_taxid_562_latest = df_taxid_562_sorted.iloc[0]  # Select the latest assembly
if len(df_taxid_562_sorted) > 1:
    df_taxid_562_latest = df_taxid_562_sorted.nlargest(1, 'genome_size')

df_taxid_562_latest
# Out:
#       #assembly_accession   bioproject       biosample      wgs_master  \
# 79721     GCF_900536975.1  PRJNA224116  SAMEA104446543  UNQS00000000.1
#
#       refseq_category taxid species_taxid     organism_name  \
# 79721              na   562           562  Escherichia coli
#
#       infraspecific_name isolate  ... replicon_count scaffold_count  \
# 79721        strain=ST73  2009_3  ...              0            138
#
#       contig_count annotation_provider                annotation_name  \
# 79721          138         NCBI RefSeq  GCF_900536975.1-RS_2024_06_17
#
#       annotation_date total_gene_count protein_coding_gene_count  \
# 79721      2024-06-17             5338                      4876
#
#       non_coding_gene_count pubmed_id
# 79721                    97        na
#
# [1 rows x 38 columns]

# %%
refseq_metadata  = refseq_metadata[refseq_metadata['infraspecific_name']!='na']

# %%
import pandas as pd

# Assuming 'refseq_metadata' is your DataFrame
def select_latest_assembly(group):
    # Sort by 'annotation_date' and convert to datetime if necessary
    group['annotation_date'] = pd.to_datetime(group['annotation_date'])
    group_sorted = group.sort_values(by='annotation_date', ascending=False)
    
    # Clean and convert 'genome_size' to numeric
    group_sorted['genome_size'] = group_sorted['genome_size'].replace({r'[^\d.]': ''}, regex=True)
    group_sorted['genome_size'] = pd.to_numeric(group_sorted['genome_size'], errors='coerce')
    
    # Select the latest assembly, and if there are still multiple rows, pick the one with the longest genome size
    latest_assembly = group_sorted.iloc[0]  # Select the latest assembly
    if len(group_sorted) > 1:
        latest_assembly = group_sorted.nlargest(1, 'genome_size').iloc[0]
    
    return latest_assembly

# Apply the function to each group (grouped by 'taxid' and 'infraspecific_name')
df_unique_assemblies = refseq_metadata.groupby(['taxid', 'infraspecific_name'], group_keys=False).apply(select_latest_assembly)

# The result will contain the unique assembly for each strain
df_unique_assemblies
# Out:
# /var/folders/65/rjhnld5s4xv_rsh25jvbsq5r0000gp/T/ipykernel_11308/2167343126.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_unique_assemblies = refseq_metadata.groupby(['taxid', 'infraspecific_name'], group_keys=False).apply(select_latest_assembly)
#                           #assembly_accession   bioproject     biosample  \
# taxid  infraspecific_name
# 100    strain=DSM 101         GCF_004339465.1  PRJNA224116  SAMN10866377
# 100053 strain=56159           GCF_002009835.1  PRJNA224116  SAMN02947886
#        strain=56640           GCF_002009825.1  PRJNA224116  SAMN02947769
#        strain=56643           GCF_002009805.1  PRJNA224116  SAMN02947770
#        strain=56650           GCF_002009775.1  PRJNA224116  SAMN02947771
# ...                                       ...          ...           ...
# 999892 strain=P08             GCF_000204235.1  PRJNA224116  SAMN02471992
# 999894 strain=S95             GCF_001652585.1  PRJNA224116  SAMN04623574
# 999931 strain=39T             GCF_910573815.1  PRJNA224116  SAMEA8751438
#        strain=DSM 24617       GCF_006716095.1  PRJNA224116  SAMN11512942
#        strain=WGS1921         GCF_043161945.1  PRJNA224116  SAMN43971778
#
#                                   wgs_master   refseq_category   taxid  \
# taxid  infraspecific_name
# 100    strain=DSM 101         SMFY00000000.1  reference genome     100
# 100053 strain=56159           JQGT00000000.1                na  100053
#        strain=56640           JQGV00000000.1                na  100053
#        strain=56643           JQGU00000000.1                na  100053
#        strain=56650           JQGS00000000.1                na  100053
# ...                                      ...               ...     ...
# 999892 strain=P08             AFAM00000000.1  reference genome  999892
# 999894 strain=S95             LWLG00000000.1  reference genome  999894
# 999931 strain=39T          CAJTBP000000000.1                na  999931
#        strain=DSM 24617       VFOK00000000.1  reference genome  999931
#        strain=WGS1921                     na                na  999931
#
#                           species_taxid                 organism_name  \
# taxid  infraspecific_name
# 100    strain=DSM 101               100        Ancylobacter aquaticus
# 100053 strain=56159              100053         Leptospira alexanderi
#        strain=56640              100053         Leptospira alexanderi
#        strain=56643              100053         Leptospira alexanderi
#        strain=56650              100053         Leptospira alexanderi
# ...                                 ...                           ...
# 999892 strain=P08               2559073    Cutibacterium modestum P08
# 999894 strain=S95                999894  Thermosulfurimonas dismutans
# 999931 strain=39T                999931        Barrientosiimonas humi
#        strain=DSM 24617          999931        Barrientosiimonas humi
#        strain=WGS1921            999931        Barrientosiimonas humi
#
#                           infraspecific_name isolate  ... replicon_count  \
# taxid  infraspecific_name                             ...
# 100    strain=DSM 101         strain=DSM 101      na  ...              0
# 100053 strain=56159             strain=56159      na  ...              0
#        strain=56640             strain=56640      na  ...              0
#        strain=56643             strain=56643      na  ...              0
#        strain=56650             strain=56650      na  ...              0
# ...                                      ...     ...  ...            ...
# 999892 strain=P08                 strain=P08      na  ...              0
# 999894 strain=S95                 strain=S95      na  ...              0
# 999931 strain=39T                 strain=39T     39T  ...              0
#        strain=DSM 24617     strain=DSM 24617      na  ...              0
#        strain=WGS1921         strain=WGS1921      na  ...              2
#
#                           scaffold_count contig_count annotation_provider  \
# taxid  infraspecific_name
# 100    strain=DSM 101                 11           11         NCBI RefSeq
# 100053 strain=56159                  337          337         NCBI RefSeq
#        strain=56640                  368          368         NCBI RefSeq
#        strain=56643                  335          335         NCBI RefSeq
#        strain=56650                  341          341         NCBI RefSeq
# ...                                  ...          ...                 ...
# 999892 strain=P08                     22           22         NCBI RefSeq
# 999894 strain=S95                     61           61         NCBI RefSeq
# 999931 strain=39T                      2            2         NCBI RefSeq
#        strain=DSM 24617                2            2         NCBI RefSeq
#        strain=WGS1921                  2            2         NCBI RefSeq
#
#                                          annotation_name annotation_date  \
# taxid  infraspecific_name
# 100    strain=DSM 101      GCF_004339465.1-RS_2024_05_01      2024-05-01
# 100053 strain=56159        GCF_002009835.1-RS_2024_07_26      2024-07-26
#        strain=56640        GCF_002009825.1-RS_2024_05_19      2024-05-19
#        strain=56643        GCF_002009805.1-RS_2024_07_26      2024-07-26
#        strain=56650        GCF_002009775.1-RS_2024_05_19      2024-05-19
# ...                                                  ...             ...
# 999892 strain=P08          GCF_000204235.1-RS_2024_03_28      2024-03-28
# 999894 strain=S95          GCF_001652585.1-RS_2024_04_21      2024-04-21
# 999931 strain=39T          GCF_910573815.1-RS_2024_03_29      2024-03-29
#        strain=DSM 24617    GCF_006716095.1-RS_2024_03_29      2024-03-29
#        strain=WGS1921      GCF_043161945.1-RS_2024_10_16      2024-10-16
#
#                           total_gene_count protein_coding_gene_count  \
# taxid  infraspecific_name
# 100    strain=DSM 101                 4513                      4381
# 100053 strain=56159                   3803                      3490
#        strain=56640                   3815                      3462
#        strain=56643                   3786                      3467
#        strain=56650                   3788                      3476
# ...                                    ...                       ...
# 999892 strain=P08                     2500                      2214
# 999894 strain=S95                     2152                      2077
# 999931 strain=39T                     3390                      3319
#        strain=DSM 24617               3422                      3354
#        strain=WGS1921                 3403                      3308
#
#                           non_coding_gene_count pubmed_id
# taxid  infraspecific_name
# 100    strain=DSM 101                        53        na
# 100053 strain=56159                          44        na
#        strain=56640                          46        na
#        strain=56643                          44        na
#        strain=56650                          42        na
# ...                                         ...       ...
# 999892 strain=P08                            53  21571999
# 999894 strain=S95                            55        na
# 999931 strain=39T                            56        na
#        strain=DSM 24617                      56        na
#        strain=WGS1921                        57        na
#
# [353848 rows x 38 columns]

# %%
df_unique_assemblies['infraspecific_name'].value_counts()
# Out:
# infraspecific_name
# strain=BIOML-A1      71
# strain=BIOML-A2      53
# strain=S1            49
# strain=BIOML-A3      49
# strain=C1            47
#                      ..
# strain=CCUG 60898     1
# strain=TA208          1
# strain=39T            1
# strain=DSM 24617      1
# strain=WGS1921        1
# Name: count, Length: 329564, dtype: int64

# %%
df_unique_assemblies.to_csv("refseq_representative_assemblies.csv")

# %%
patric_metadata['strain'].value_counts()
# Out:
# strain
# B31 5A4                   966
# CO275                     769
# Neisseria meningitidis    542
# B31 5A3                   439
# 5A18NP1                   284
#                          ...
# YR_bin-0414                 1
# YR_bin-2355                 1
# N43453                      1
# N43451                      1
# N43450                      1
# Name: count, Length: 878075, dtype: int64

# %%
patric_metadata = patric_metadata[patric_metadata['strain']!='not applicable']
patric_metadata = patric_metadata[patric_metadata['strain']!='Not applicable']
patric_metadata = patric_metadata[patric_metadata['strain']!='Fecal samples']
patric_metadata = patric_metadata[patric_metadata['strain']!='not collected']

# %%
patric_metadata.columns
# Out:
# Index(['genome_id', 'genome_name', 'organism_name', 'taxon_id',
#        'genome_status', 'strain', 'serovar', 'biovar', 'pathovar', 'mlst',
#        'other_typing', 'culture_collection', 'type_strain', 'completion_date',
#        'publication', 'bioproject_accession', 'biosample_accession',
#        'assembly_accession', 'genbank_accessions', 'refseq_accessions',
#        'sequencing_centers', 'sequencing_status', 'sequencing_platform',
#        'sequencing_depth', 'assembly_method', 'chromosomes', 'plasmids',
#        'contigs', 'sequences', 'genome_length', 'gc_content', 'patric_cds',
#        'brc1_cds', 'refseq_cds', 'isolation_site', 'isolation_source',
#        'isolation_comments', 'collection_date', 'isolation_country',
#        'geographic_location', 'latitude', 'longitude', 'altitude', 'depth',
#        'other_environmental', 'host_name', 'host_gender', 'host_age',
#        'host_health', 'body_sample_site', 'body_sample_subsite',
#        'other_clinical', 'antimicrobial_resistance',
#        'antimicrobial_resistance_evidence', 'gram_stain', 'cell_shape',
#        'motility', 'sporulation', 'temperature_range', 'optimal_temperature',
#        'salinity', 'oxygen_requirement', 'habitat', 'disease', 'comments',
#        'additional_metadata'],
#       dtype='object')

# %%
df_unique_assemblies_patric.to_csv("patric_representative_assemblies.csv")

# %%
import pandas as pd

# Assuming 'refseq_metadata' is your DataFrame
def select_latest_assembly(group):
    # Sort by 'annotation_date' and convert to datetime if necessary
    group['completion_date'] = pd.to_datetime(group['completion_date'])
    group_sorted = group.sort_values(by='completion_date', ascending=False)
    
    # Clean and convert 'genome_size' to numeric
    group_sorted['genome_length'] = group_sorted['genome_length'].replace({r'[^\d.]': ''}, regex=True)
    group_sorted['genome_length'] = pd.to_numeric(group_sorted['genome_length'], errors='coerce')
    
    # Select the latest assembly, and if there are still multiple rows, pick the one with the longest genome size
    latest_assembly = group_sorted.iloc[0]  # Select the latest assembly
    if len(group_sorted) > 1:
        latest_assembly = group_sorted.nlargest(1, 'genome_length').iloc[0]
    
    return latest_assembly

# Apply the function to each group (grouped by 'taxid' and 'infraspecific_name')
df_unique_assemblies_patric = patric_metadata.groupby(['taxon_id', 'strain'], group_keys=False).apply(select_latest_assembly)

# The result will contain the unique assembly for each strain
df_unique_assemblies_patric

# %%
df_unique_assemblies_patric
# Out:
#                     genome_id  \
# taxon_id strain
# 100      DSM 101       100.11
#          UV5            100.9
# 100053   56159       100053.7
#          56640       100053.6
#          56643       100053.5
# ...                       ...
# 999894   HyVt-483   999894.10
#          S95         999894.9
# 999898   CEB3        999898.5
# 999931   39T         999931.5
#          DSM 24617   999931.3
#
#                                                           genome_name  \
# taxon_id strain
# 100      DSM 101                Ancylobacter aquaticus strain DSM 101
#          UV5                        Ancylobacter aquaticus strain UV5
# 100053   56159                     Leptospira alexanderi strain 56159
#          56640                     Leptospira alexanderi strain 56640
#          56643                     Leptospira alexanderi strain 56643
# ...                                                               ...
# 999894   HyVt-483        Thermosulfurimonas dismutans strain HyVt-483
#          S95                  Thermosulfurimonas dismutans strain S95
# 999898   CEB3                           Peptococcaceae bacterium CEB3
# 999931   39T        Barrientosiimonas humi strain type strain: 39 ...
#          DSM 24617            Barrientosiimonas humi strain DSM 24617
#
#                    organism_name taxon_id genome_status     strain serovar  \
# taxon_id strain
# 100      DSM 101             NaN      100           WGS    DSM 101     NaN
#          UV5                 NaN      100           WGS        UV5     NaN
# 100053   56159               NaN   100053           WGS      56159     NaN
#          56640               NaN   100053           WGS      56640     NaN
#          56643               NaN   100053           WGS      56643     NaN
# ...                          ...      ...           ...        ...     ...
# 999894   HyVt-483            NaN   999894           WGS   HyVt-483     NaN
#          S95                 NaN   999894           WGS        S95     NaN
# 999898   CEB3                NaN   999898           WGS       CEB3     NaN
# 999931   39T                 NaN   999931           WGS        39T     NaN
#          DSM 24617           NaN   999931           WGS  DSM 24617     NaN
#
#                    biovar pathovar mlst  ... motility sporulation  \
# taxon_id strain                          ...
# 100      DSM 101      NaN      NaN  NaN  ...      NaN         NaN
#          UV5          NaN      NaN  NaN  ...      NaN         NaN
# 100053   56159        NaN      NaN  NaN  ...      NaN         NaN
#          56640        NaN      NaN  NaN  ...      NaN         NaN
#          56643        NaN      NaN  NaN  ...      NaN         NaN
# ...                   ...      ...  ...  ...      ...         ...
# 999894   HyVt-483     NaN      NaN  NaN  ...      NaN         NaN
#          S95          NaN      NaN  NaN  ...      NaN         NaN
# 999898   CEB3         NaN      NaN  NaN  ...      NaN         NaN
# 999931   39T          NaN      NaN  NaN  ...      NaN         NaN
#          DSM 24617    NaN      NaN  NaN  ...      NaN         NaN
#
#                    temperature_range optimal_temperature salinity  \
# taxon_id strain
# 100      DSM 101                 NaN                 NaN      NaN
#          UV5                     NaN                 NaN      NaN
# 100053   56159                   NaN                 NaN      NaN
#          56640                   NaN                 NaN      NaN
#          56643                   NaN                 NaN      NaN
# ...                              ...                 ...      ...
# 999894   HyVt-483                NaN                 NaN      NaN
#          S95                     NaN                 NaN      NaN
# 999898   CEB3                    NaN                   C      NaN
# 999931   39T                     NaN                 NaN      NaN
#          DSM 24617               NaN                 NaN      NaN
#
#                    oxygen_requirement habitat disease  \
# taxon_id strain
# 100      DSM 101                  NaN     NaN     NaN
#          UV5                      NaN     NaN     NaN
# 100053   56159                    NaN     NaN     NaN
#          56640                    NaN     NaN     NaN
#          56643                    NaN     NaN     NaN
# ...                               ...     ...     ...
# 999894   HyVt-483                 NaN     NaN     NaN
#          S95                      NaN     NaN     NaN
# 999898   CEB3                     NaN     NaN     NaN
# 999931   39T                      NaN     NaN     NaN
#          DSM 24617                NaN     NaN     NaN
#
#                                                              comments  \
# taxon_id strain
# 100      DSM 101    Genome sequencing as part of The One Thousand ...
#          UV5        Ancylobacter aquaticus sp. strain UV5, isolate...
# 100053   56159      Comparative genomics analysis of 102 Leptospir...
#          56640      Comparative genomics analysis of 102 Leptospir...
#          56643      Comparative genomics analysis of 102 Leptospir...
# ...                                                               ...
# 999894   HyVt-483   This is the collection of metagenome-assembled...
#          S95        The genome sequncing and analysis of Thermosul...
# 999898   CEB3       Strain CEB3 is an acidophilic sulfate reducing...
# 999931   39T        A genomic analysis study presents the whole-ge...
#          DSM 24617  Sequencing of Actinobacteria genome as a plant...
#
#                                  additional_metadata
# taxon_id strain
# 100      DSM 101                                 NaN
#          UV5                                     NaN
# 100053   56159                                   NaN
#          56640               collected_by:Jincai Qin
#          56643               collected_by:Jincai Qin
# ...                                              ...
# 999894   HyVt-483   sample_type:metagenomic assembly
#          S95                                     NaN
# 999898   CEB3             sample_type:whole organism
# 999931   39T                                     NaN
#          DSM 24617                               NaN
#
# [912435 rows x 66 columns]

# %%
df_unique_assemblies_refseq = pd.read_csv("refseq_representative_assemblies.csv",dtype=str)

# %%
df_unique_assemblies_patric = pd.read_csv("patric_representative_assemblies.csv",dtype=str)

# %%
# Rename columns in the final result
df_unique_assemblies_refseq = df_unique_assemblies_refseq.rename(columns={'taxid': 'taxon_id', 'infraspecific_name': 'strain'})

# The result will now have 'taxon_id' and 'strain' as column names
df_unique_assemblies_refseq
# Out:
#        taxon_id            strain #assembly_accession   bioproject  \
# 0           100    strain=DSM 101     GCF_004339465.1  PRJNA224116
# 1        100053      strain=56159     GCF_002009835.1  PRJNA224116
# 2        100053      strain=56640     GCF_002009825.1  PRJNA224116
# 3        100053      strain=56643     GCF_002009805.1  PRJNA224116
# 4        100053      strain=56650     GCF_002009775.1  PRJNA224116
# ...         ...               ...                 ...          ...
# 353843   999892        strain=P08     GCF_000204235.1  PRJNA224116
# 353844   999894        strain=S95     GCF_001652585.1  PRJNA224116
# 353845   999931        strain=39T     GCF_910573815.1  PRJNA224116
# 353846   999931  strain=DSM 24617     GCF_006716095.1  PRJNA224116
# 353847   999931    strain=WGS1921     GCF_043161945.1  PRJNA224116
#
#            biosample         wgs_master   refseq_category taxid.1  \
# 0       SAMN10866377     SMFY00000000.1  reference genome     100
# 1       SAMN02947886     JQGT00000000.1                na  100053
# 2       SAMN02947769     JQGV00000000.1                na  100053
# 3       SAMN02947770     JQGU00000000.1                na  100053
# 4       SAMN02947771     JQGS00000000.1                na  100053
# ...              ...                ...               ...     ...
# 353843  SAMN02471992     AFAM00000000.1  reference genome  999892
# 353844  SAMN04623574     LWLG00000000.1  reference genome  999894
# 353845  SAMEA8751438  CAJTBP000000000.1                na  999931
# 353846  SAMN11512942     VFOK00000000.1  reference genome  999931
# 353847  SAMN43971778                 na                na  999931
#
#        species_taxid                 organism_name  ... replicon_count  \
# 0                100        Ancylobacter aquaticus  ...              0
# 1             100053         Leptospira alexanderi  ...              0
# 2             100053         Leptospira alexanderi  ...              0
# 3             100053         Leptospira alexanderi  ...              0
# 4             100053         Leptospira alexanderi  ...              0
# ...              ...                           ...  ...            ...
# 353843       2559073    Cutibacterium modestum P08  ...              0
# 353844        999894  Thermosulfurimonas dismutans  ...              0
# 353845        999931        Barrientosiimonas humi  ...              0
# 353846        999931        Barrientosiimonas humi  ...              0
# 353847        999931        Barrientosiimonas humi  ...              2
#
#        scaffold_count contig_count annotation_provider  \
# 0                  11           11         NCBI RefSeq
# 1                 337          337         NCBI RefSeq
# 2                 368          368         NCBI RefSeq
# 3                 335          335         NCBI RefSeq
# 4                 341          341         NCBI RefSeq
# ...               ...          ...                 ...
# 353843             22           22         NCBI RefSeq
# 353844             61           61         NCBI RefSeq
# 353845              2            2         NCBI RefSeq
# 353846              2            2         NCBI RefSeq
# 353847              2            2         NCBI RefSeq
#
#                       annotation_name annotation_date total_gene_count  \
# 0       GCF_004339465.1-RS_2024_05_01      2024-05-01             4513
# 1       GCF_002009835.1-RS_2024_07_26      2024-07-26             3803
# 2       GCF_002009825.1-RS_2024_05_19      2024-05-19             3815
# 3       GCF_002009805.1-RS_2024_07_26      2024-07-26             3786
# 4       GCF_002009775.1-RS_2024_05_19      2024-05-19             3788
# ...                               ...             ...              ...
# 353843  GCF_000204235.1-RS_2024_03_28      2024-03-28             2500
# 353844  GCF_001652585.1-RS_2024_04_21      2024-04-21             2152
# 353845  GCF_910573815.1-RS_2024_03_29      2024-03-29             3390
# 353846  GCF_006716095.1-RS_2024_03_29      2024-03-29             3422
# 353847  GCF_043161945.1-RS_2024_10_16      2024-10-16             3403
#
#        protein_coding_gene_count non_coding_gene_count pubmed_id
# 0                           4381                    53        na
# 1                           3490                    44        na
# 2                           3462                    46        na
# 3                           3467                    44        na
# 4                           3476                    42        na
# ...                          ...                   ...       ...
# 353843                      2214                    53  21571999
# 353844                      2077                    55        na
# 353845                      3319                    56        na
# 353846                      3354                    56        na
# 353847                      3308                    57        na
#
# [353848 rows x 40 columns]

# %%
# Remove "strain=" from every value in the 'strain' column
df_unique_assemblies_refseq['strain'] = df_unique_assemblies_refseq['strain'].str.replace('strain=', '', regex=False)

# The result will have "strain=" removed from the 'strain' column
df_unique_assemblies_refseq
# Out:
#        taxon_id     strain #assembly_accession   bioproject     biosample  \
# 0           100    DSM 101     GCF_004339465.1  PRJNA224116  SAMN10866377
# 1        100053      56159     GCF_002009835.1  PRJNA224116  SAMN02947886
# 2        100053      56640     GCF_002009825.1  PRJNA224116  SAMN02947769
# 3        100053      56643     GCF_002009805.1  PRJNA224116  SAMN02947770
# 4        100053      56650     GCF_002009775.1  PRJNA224116  SAMN02947771
# ...         ...        ...                 ...          ...           ...
# 353843   999892        P08     GCF_000204235.1  PRJNA224116  SAMN02471992
# 353844   999894        S95     GCF_001652585.1  PRJNA224116  SAMN04623574
# 353845   999931        39T     GCF_910573815.1  PRJNA224116  SAMEA8751438
# 353846   999931  DSM 24617     GCF_006716095.1  PRJNA224116  SAMN11512942
# 353847   999931    WGS1921     GCF_043161945.1  PRJNA224116  SAMN43971778
#
#                wgs_master   refseq_category taxid.1 species_taxid  \
# 0          SMFY00000000.1  reference genome     100           100
# 1          JQGT00000000.1                na  100053        100053
# 2          JQGV00000000.1                na  100053        100053
# 3          JQGU00000000.1                na  100053        100053
# 4          JQGS00000000.1                na  100053        100053
# ...                   ...               ...     ...           ...
# 353843     AFAM00000000.1  reference genome  999892       2559073
# 353844     LWLG00000000.1  reference genome  999894        999894
# 353845  CAJTBP000000000.1                na  999931        999931
# 353846     VFOK00000000.1  reference genome  999931        999931
# 353847                 na                na  999931        999931
#
#                        organism_name  ... replicon_count scaffold_count  \
# 0             Ancylobacter aquaticus  ...              0             11
# 1              Leptospira alexanderi  ...              0            337
# 2              Leptospira alexanderi  ...              0            368
# 3              Leptospira alexanderi  ...              0            335
# 4              Leptospira alexanderi  ...              0            341
# ...                              ...  ...            ...            ...
# 353843    Cutibacterium modestum P08  ...              0             22
# 353844  Thermosulfurimonas dismutans  ...              0             61
# 353845        Barrientosiimonas humi  ...              0              2
# 353846        Barrientosiimonas humi  ...              0              2
# 353847        Barrientosiimonas humi  ...              2              2
#
#        contig_count annotation_provider                annotation_name  \
# 0                11         NCBI RefSeq  GCF_004339465.1-RS_2024_05_01
# 1               337         NCBI RefSeq  GCF_002009835.1-RS_2024_07_26
# 2               368         NCBI RefSeq  GCF_002009825.1-RS_2024_05_19
# 3               335         NCBI RefSeq  GCF_002009805.1-RS_2024_07_26
# 4               341         NCBI RefSeq  GCF_002009775.1-RS_2024_05_19
# ...             ...                 ...                            ...
# 353843           22         NCBI RefSeq  GCF_000204235.1-RS_2024_03_28
# 353844           61         NCBI RefSeq  GCF_001652585.1-RS_2024_04_21
# 353845            2         NCBI RefSeq  GCF_910573815.1-RS_2024_03_29
# 353846            2         NCBI RefSeq  GCF_006716095.1-RS_2024_03_29
# 353847            2         NCBI RefSeq  GCF_043161945.1-RS_2024_10_16
#
#        annotation_date total_gene_count protein_coding_gene_count  \
# 0           2024-05-01             4513                      4381
# 1           2024-07-26             3803                      3490
# 2           2024-05-19             3815                      3462
# 3           2024-07-26             3786                      3467
# 4           2024-05-19             3788                      3476
# ...                ...              ...                       ...
# 353843      2024-03-28             2500                      2214
# 353844      2024-04-21             2152                      2077
# 353845      2024-03-29             3390                      3319
# 353846      2024-03-29             3422                      3354
# 353847      2024-10-16             3403                      3308
#
#        non_coding_gene_count pubmed_id
# 0                         53        na
# 1                         44        na
# 2                         46        na
# 3                         44        na
# 4                         42        na
# ...                      ...       ...
# 353843                    53  21571999
# 353844                    55        na
# 353845                    56        na
# 353846                    56        na
# 353847                    57        na
#
# [353848 rows x 40 columns]

# %%
df_unique_assemblies_patric.columns
# Out:
# Index(['taxon_id', 'strain', 'genome_id', 'genome_name', 'organism_name',
#        'taxon_id.1', 'genome_status', 'strain.1', 'serovar', 'biovar',
#        'pathovar', 'mlst', 'other_typing', 'culture_collection', 'type_strain',
#        'completion_date', 'publication', 'bioproject_accession',
#        'biosample_accession', 'assembly_accession', 'genbank_accessions',
#        'refseq_accessions', 'sequencing_centers', 'sequencing_status',
#        'sequencing_platform', 'sequencing_depth', 'assembly_method',
#        'chromosomes', 'plasmids', 'contigs', 'sequences', 'genome_length',
#        'gc_content', 'patric_cds', 'brc1_cds', 'refseq_cds', 'isolation_site',
#        'isolation_source', 'isolation_comments', 'collection_date',
#        'isolation_country', 'geographic_location', 'latitude', 'longitude',
#        'altitude', 'depth', 'other_environmental', 'host_name', 'host_gender',
#        'host_age', 'host_health', 'body_sample_site', 'body_sample_subsite',
#        'other_clinical', 'antimicrobial_resistance',
#        'antimicrobial_resistance_evidence', 'gram_stain', 'cell_shape',
#        'motility', 'sporulation', 'temperature_range', 'optimal_temperature',
#        'salinity', 'oxygen_requirement', 'habitat', 'disease', 'comments',
#        'additional_metadata'],
#       dtype='object')

# %%
# Rename the index levels to 'name1' and 'name2'
df_patric_unique = df_unique_assemblies_patric.rename_axis(index={'taxon_id': 'name1', 'strain': 'name2'}).reset_index()
df_refseq_unique = df_unique_assemblies_refseq.rename_axis(index={'taxon_id': 'name1', 'strain': 'name2'}).reset_index()
# Assuming the two DataFrames are df1 and df2
common_taxon_strain = pd.merge(df_patric_unique[['taxon_id', 'strain']], df_refseq_unique[['taxon_id', 'strain']], 
                                on=['taxon_id', 'strain'], how='inner')

# The result will contain the common unique combinations of 'taxon_id' and 'strain'
common_taxon_strain
# Out:
#        taxon_id     strain
# 0           100    DSM 101
# 1        100053      56159
# 2        100053      56640
# 3        100053      56643
# 4        100053      56650
# ...         ...        ...
# 295050   999891      TA208
# 295051   999892        P08
# 295052   999894        S95
# 295053   999931        39T
# 295054   999931  DSM 24617
#
# [295055 rows x 2 columns]

# %%
# Perform the merge, keeping 'genome_id' from patric and 'ftp_path' from refseq
common_taxon_strain = pd.merge(
    df_patric_unique[['taxon_id', 'strain', 'genome_id','contigs']], 
    df_refseq_unique[['taxon_id', 'strain', 'ftp_path','contig_count']], 
    on=['taxon_id', 'strain'], 
    how='inner'
)

# The result will contain the common unique combinations of 'taxon_id' and 'strain'
# along with 'genome_id' from patric and 'ftp_path' from refseq
# Rename the 'contigs' column to 'contigs_patric'
common_taxon_strain = common_taxon_strain.rename(columns={'contigs': 'contigs_patric'})

# The result will have the 'contigs' column renamed to 'contigs_patric'
common_taxon_strain
# Out:
#        taxon_id     strain genome_id contigs_patric  \
# 0           100    DSM 101    100.11             11
# 1        100053      56159  100053.7            337
# 2        100053      56640  100053.6            368
# 3        100053      56643  100053.5            335
# 4        100053      56650  100053.4            341
# ...         ...        ...       ...            ...
# 295050   999891      TA208  999891.3              1
# 295051   999892        P08  999892.3             22
# 295052   999894        S95  999894.9             61
# 295053   999931        39T  999931.5              2
# 295054   999931  DSM 24617  999931.3              2
#
#                                                  ftp_path contig_count
# 0       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...           11
# 1       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...          337
# 2       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...          368
# 3       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...          335
# 4       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...          341
# ...                                                   ...          ...
# 295050  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# 295051  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...           22
# 295052  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...           61
# 295053  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/9...            2
# 295054  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            2
#
# [295055 rows x 6 columns]

# %%
# First DataFrame where contigs_patric = "1" and contig_count = "1"
df_contigs_one = common_taxon_strain[(common_taxon_strain['contigs_patric'] == "1") & 
                                     (common_taxon_strain['contig_count'] == "1")]

# Second DataFrame containing the remaining rows
df_remaining = common_taxon_strain[~((common_taxon_strain['contigs_patric'] == "1") & 
                                     (common_taxon_strain['contig_count'] == "1"))]

# df_contigs_one contains rows where contigs_patric = "1" and contig_count = "1"
# df_remaining contains the remaining rows
df_contigs_one
# Out:
#        taxon_id        strain   genome_id contigs_patric  \
# 25      1001534        TI0902   1001534.3              1
# 26      1001542        TIGB03   1001542.3              1
# 29      1001585         NK-01   1001585.3              1
# 92       100226  CFB_NBC_0001  100226.137              1
# 103     1002672      IMCC9063   1002672.3              1
# ...         ...           ...         ...            ...
# 294973    99822    DB60705-15    99822.28              1
# 294975    99822      NCTC4669    99822.25              1
# 294989    99822    STREP97-15    99822.29              1
# 294996   999183     DSM 25104    999183.3              1
# 295050   999891         TA208    999891.3              1
#
#                                                  ftp_path contig_count
# 25      https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# 26      https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# 29      https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# 92      https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# 103     https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# ...                                                   ...          ...
# 294973  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# 294975  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/9...            1
# 294989  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# 294996  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
# 295050  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            1
#
# [21109 rows x 6 columns]

# %%
df_remaining.to_csv("common_strains_with_multiple_contigs.csv")
df_contigs_one.to_csv("common_strains_with_one_contig.csv")

# %%
df_remaining
# Out:
#        taxon_id                        strain genome_id contigs_patric  \
# 0           100                       DSM 101    100.11             11
# 1        100053                         56159  100053.7            337
# 2        100053                         56640  100053.6            368
# 3        100053                         56643  100053.5            335
# 4        100053                         56650  100053.4            341
# ...         ...                           ...       ...            ...
# 295049   999700  JA576,NBRC 108863,KCTC 15144  999700.3             69
# 295051   999892                           P08  999892.3             22
# 295052   999894                           S95  999894.9             61
# 295053   999931                           39T  999931.5              2
# 295054   999931                     DSM 24617  999931.3              2
#
#                                                  ftp_path contig_count
# 0       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...           11
# 1       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...          337
# 2       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...          368
# 3       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...          335
# 4       https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...          341
# ...                                                   ...          ...
# 295049  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...           69
# 295051  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...           22
# 295052  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...           61
# 295053  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/9...            2
# 295054  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...            2
#
# [273946 rows x 6 columns]
